# %% [markdown]
# # Slope

# %% [markdown]
# Slope is nothing but delta y divide by delta x, when u have linear line the one below,
# ![image.png](attachment:image.png)
# the slope for this particular line would be 3 because delta y whicis between 6 and 9 is 3 divide by delta x which is between 2 and 3 which is 1
#
# so deltay/deltax = 3/1 = 3
#
# thats why the slope of this line is 3, its very simple math
# ![image-2.png](attachment:image-2.png)
#
# But, when you have a line like this which is not linear, the slope is not constant
# ![image-3.png](attachment:image-3.png)
# based on what ur looking at, the slope might vary, so how do u find the slope of this line? well what we can do is, we can zoom in a little bit
# ![image-4.png](attachment:image-4.png)
# And when u zoom in, this particular line segment look like a straight line so u can still use delta y / delta x
# ![image-5.png](attachment:image-5.png)
#
# Here, u will have to take a very small delta x, we took this explanation from mathisfun.com, its an amazing website to understand math concept,
# ![image-6.png](attachment:image-6.png)
# so if u go through the equation u will find out that the slope or Derivative of x<sup>2</sup> comes to be 2x.
#
# So the slope here is not a constant, its a function and thats why its called a Derivative.
#
# Derivative and Slope are kind of similar but Derivative is used for non-linear equations

# %% [markdown]
# # Derivative

# %% [markdown]
# OK, so what does that 2x mean really?
# ![image.png](attachment:image.png)
# So if ur looking at any point, for example here, when x=2 the slope is 4 and when x = 5 the slope is 10
# ![image-2.png](attachment:image-2.png)
# So the slopes vary between different points on the line, thats why we need to use a Function to represent this slope and that function is nothing but Derivative

# %% [markdown]
# There are certain Derivative rules, u can go to this website see different derivative rules
#
# Website = "https://www.mathsisfun.com/calculus/derivatives-introduction.html"
#
# So when you have equation like this
# ![image.png](attachment:image.png)
# For the first equation, all you do is you put that <sup>3</sup> infront of x so it becomes 3x<sup>3</sup> and then substarct the <sup>3</sup> from 1 so you get 3x<sup>2</sup>
#
# And for second equation, u do the same, put  <sup>3</sup> in front of x so it becomes 7 3x and then substract  <sup>3</sup> from 1 so u get  <sup>2</sup> so u get 7 3x<sup>2</sup> so you just multiply 7 x 3 = 21 so your Derivative will be 21x<sup>2</sup>
# ![image-2.png](attachment:image-2.png)
#
# Because 3 came in front, it got multiplied by 7 so u get 21 and then u simply substract 1 from the 3 above (<sup>3</sup>) so u get 21x<sup>2</sup>
#
# <br>
#
# When u have equation like this
# ![image-3.png](attachment:image-3.png)
# you can do the same thing and apply the power rule on individual component
#
# so for 2x<sup>3</sup> you bring the <sup>3</sup> infront the multiply it by 2 so u get 6x then substract <sup>3</sup> from 1 so u get 6x<sup>2</sup>
#
# for x<sup>5</sup>, u simply bring the 5 infront and substract <sup>5</sup> from 1 so u get 5x<sup>4</sup>
#
# so ultimatly u get 6x<sup>2</sup> + 5x<sup>4</sup>
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # Slope and Derivative difference
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Partial Derivative
#
# Partial derivative is as easy as derivative,
#
# so when u have equation like this where u have 2 variables x and y
# ![image.png](attachment:image.png)
# To find the Partial derivative of your function with respect to X, all you do is, you consider that y doesnt exist, so you make it 0, and u find the Derivative of X<sup>3</sup> which will be 3X<sup>2</sup>, so thats your Partial derivative
# ![image-2.png](attachment:image-2.png)
#
# Same thing u do with y by condsidring that X doesnt exist so ur Partial derivative is 2y, its SUPER EASY!
# ![image-3.png](attachment:image-3.png)
# ALHAMDULILLAH! THANKS TO ALLAH FOR MAKING ME BE ABLE TO UNDERSTAND AND COMPREHEND ALL OF THESE, WITHOUT ALLAH I WONT BE ABLE TO UNDERSTAND A THING, SO THANK YOU ALLAH, YOU ARE THE BEST!!!!

# %% [markdown]
# # Mathisfun.com
# Codebasics recommended to go to this website and go throught and understand Derivative and Derivative rules and Partial Derivative as well, it will be very useful for Deep Learning
#
# Website = "https://www.mathsisfun.com/calculus/derivatives-introduction.html"

# %% [markdown]
# # Why to learn Derivative and what its uses in Deep Learning?
#
# So think about this, we have looked at this equation where we talk about Partial Derivative of X and Y
# ![image.png](attachment:image.png)
#
# Instead of using X and Y, lets use House price prediction examples and lets say our X is num of bedrooms and y is sqrfoot and this func is trying to predict price of the home based on bedroom and sqtft
# ![image-2.png](attachment:image-2.png)
#
# So we have exactly the same equation, we just replaced X and Y with Bedrooms and sqrft
#
# When u find the partial derivative of price with respect to bedrooms, u might find a derivative equation which look like this, What this tells you is, How much a price is changing given a change in **Bedrooms**
# ![image-4.png](attachment:image-4.png)
#
# Similarly, Partial derivative of price with respect to sqr ft is telling u how much a price is changing given a change in sqr ft
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# When we have a neural network and when we do training like this, for example we are using Insurance dataset here
# ![image.png](attachment:image.png)
# Where u will feed each of those samples one by one to your network and initially your Weigts will be initialized to a random value,
#
# lets say 1 then it calculate the weighted sum and apply an Activation function (lets say Sigmoid here) and it gives you ypredicted which is **0.99**
#
# then u just compare it with the actual value and u find the **Error**
#
# Based on this Error, you want to update or modify the Weights (W1 and W2).
#
# So this is more like a Trial and Error approach with some discipline and some maths involved, so Neural Network training is all about Adjusting weights, once u get the right Weight, your Neural Network is Trained, so its a game of adjusting Weights, and u want to adjust the Weights in a Discipline and proper way so u dont get caught up in an infinite loop, And **Derivatives** helps u do that!
#
# ![image-2.png](attachment:image-2.png)
# So here what we will be doing is, taking a Derivaive of Error with respect to Age (How much the likelihood of a person buying an insurance changes based on a change in Age)
#
# Similarly, taking a Derivative of Error with respect to affordability (How much the likelihood of a person buying an insurance changes based on a change in affordability)
#
# So this concept is represented by **Partial Derivative**
#
# So it will be the **Partial derivative of Error with respect to age** and **Partial derivative of Error with respect to affordability**
